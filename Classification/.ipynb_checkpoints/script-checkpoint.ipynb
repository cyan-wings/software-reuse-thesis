# %%
import pandas as pd
import numpy as np
import math

# %%
f = pd.read_csv('best_vt_r.csv', sep=',', keep_default_na=True)
f
# Out:
#     F1-Score  Precision    Recall  Accuracy
# 0   0.778525   0.783300  0.777100  0.798500  \
# 1   0.761850   0.759725  0.767100  0.781475
# 2   0.783200   0.764650  0.805000  0.796600
# 3   0.779750   0.757275  0.806275  0.791850
# 4   0.747425   0.666525  0.862475  0.732125
# 5   0.711875   0.707575  0.720475  0.735000
# 6   0.780650   0.780875  0.782950  0.799250
# 7   0.774400   0.782775  0.769575  0.795900
# 8   0.779525   0.729125  0.840425  0.782800
# 9   0.755850   0.746350  0.768300  0.773700
# 10  0.774000   0.781525  0.769200  0.795250
#
#                                                 Model  Num_Features
# 0   RandomForestClassifier(n_estimators=500, n_job...           495  \
# 1   MLPClassifier(max_iter=10000, random_state=270...           495
# 2            SVC(gamma='auto', random_state=27033074)           495
# 3     KNeighborsClassifier(n_jobs=-1, n_neighbors=10)           495
# 4   SGDClassifier(loss='log', n_jobs=-1, random_st...           495
# 5       DecisionTreeClassifier(random_state=27033074)           495
# 6                                 RidgeClassifierCV()           495
# 7   XGBClassifier(base_score=None, booster=None, c...           495
# 8    GaussianProcessClassifier(random_state=27033074)           495
# 9           AdaBoostClassifier(random_state=27033074)           495
# 10  GradientBoostingClassifier(n_estimators=500, r...           495
#
#                                         Preprocessing  Fea_Selection
# 0                                    StandardScaler()            NaN  \
# 1                                  PowerTransformer()            NaN
# 2          QuantileTransformer(random_state=27033074)            NaN
# 3          QuantileTransformer(random_state=27033074)            NaN
# 4                                           normalize            NaN
# 5                                      MinMaxScaler()            NaN
# 6          QuantileTransformer(random_state=27033074)            NaN
# 7                                      MaxAbsScaler()            NaN
# 8                                           normalize            NaN
# 9   QuantileTransformer(output_distribution='norma...            NaN
# 10                                                NaN            NaN
#
#     Dim_Reduction  Var_Threshold  support  resampling
# 0               0           True       60        True
# 1               0          False       60       False
# 2               0           True       60        True
# 3               0          False       60       False
# 4               0          False       60       False
# 5               0           True       60        True
# 6               0          False       60       False
# 7               0          False       60       False
# 8               0          False       60       False
# 9               0           True       60        True
# 10              0           True       60       False

# %%
array = []
for i in f.Model:
    string = ''
    for c in i:
        if c == '(':
            break
        string += c

    if string == 'RandomForestClassifier':
        i = 'RF'
    elif string == 'MLPClassifier':
        i = 'MLP'
    elif string == 'SVC':
        i = 'SVM'
    elif string == 'KNeighborsClassifier':
        i = 'KNN'
    elif string == 'SGDClassifier':
        i = 'LGR'
    elif string == 'DecisionTreeClassifier':
        i = 'DT'
    elif string == 'RidgeClassifierCV':
        i = 'R'
    elif string == 'XGBClassifier':
        i = 'XG'
    elif string == 'GaussianProcessClassifier':
        i = 'GPC'
    elif string == 'AdaBoostClassifier':
        i = 'ADA'
    elif string == 'GradientBoostingClassifier':
        i = 'GB'

    array.append(i)
f.Model = array

# %%
array = []
for i in f.Preprocessing:
    string = i

    if string == 'StandardScaler()':
        i = 'StandardScaler'
    elif string == 'MinMaxScaler()':
        i = 'Min-maxScaler'
    elif string == 'MaxAbsScaler()':
        i = 'Max-absoluteScaler'
    elif string == 'RobustScaler()':
        i = 'RobustScaler'
    elif string == 'PowerTransformer()':
        i = 'PowerTransformer'
    elif string == 'QuantileTransformer(random_state=27033074)':
        i = 'QuantileTransformer_Uniform'
    elif string == "QuantileTransformer(output_distribution='normal', random_state=27033074)":
        i = 'QuantileTransformer_Normal'
    elif string == 'normalize':
        i = 'Normalisation'

    array.append(i)
f.Preprocessing = array

# %%
array = []
for i in f['F1-Score']:
    array.append(round(i, 4))
f['F1-Score'] = array

# %%
array = []
for i in f['Precision']:
    array.append(round(i, 4))
f.Precision = array

# %%
array = []
for i in f['Recall']:
    array.append(round(i, 4))
f.Recall = array

# %%
array = []
for i in f['Accuracy']:
    array.append(round(i, 4))
f.Accuracy = array

# %%
array = []
for i in range(len(f.index)):
    array.append(False)
f['Resampling'] = array

# %%
f = f.drop(['support', 'Fea_Selection', 'Dim_Reduction'], axis=1)

# %%
f
# Out:
#     F1-Score  Precision  Recall  Accuracy Model  Num_Features
# 0     0.7785     0.7833  0.7771    0.7985    RF           495  \
# 1     0.7618     0.7597  0.7671    0.7815   MLP           495
# 2     0.7832     0.7646  0.8050    0.7966   SVM           495
# 3     0.7797     0.7573  0.8063    0.7918   KNN           495
# 4     0.7474     0.6665  0.8625    0.7321   LGR           495
# 5     0.7119     0.7076  0.7205    0.7350    DT           495
# 6     0.7806     0.7809  0.7829    0.7993     R           495
# 7     0.7744     0.7828  0.7696    0.7959    XG           495
# 8     0.7795     0.7291  0.8404    0.7828   GPC           495
# 9     0.7559     0.7463  0.7683    0.7737   ADA           495
# 10    0.7740     0.7815  0.7692    0.7953    GB           495
#
#                   Preprocessing  Var_Threshold  resampling
# 0                StandardScaler           True        True
# 1              PowerTransformer          False       False
# 2   QuantileTransformer_Uniform           True        True
# 3   QuantileTransformer_Uniform          False       False
# 4                 Normalisation          False       False
# 5                 Min-maxScaler           True        True
# 6   QuantileTransformer_Uniform          False       False
# 7            Max-absoluteScaler          False       False
# 8                 Normalisation          False       False
# 9    QuantileTransformer_Normal           True        True
# 10                          NaN           True       False

# %%
f.to_csv('Optimal_VarianceThreshold_Resampling.csv', index=False)

# %%
len(f.index)
# Out:
# 11
