# %%
import pandas as pd
import numpy as np
import math

# %%
f = pd.read_csv('best-feature-selection.csv', sep=',', keep_default_na=True)
f
# Out:
#     R-square         MAE        RSME      MedAE
# 0   0.318175   74.509750  119.648850  41.775900  \
# 1   0.279225   73.394025  122.765600  39.682975
# 2   0.295025   72.768300  121.626675  38.292000
# 3   0.275425   76.111225  123.070375  41.089350
# 4  -0.006950   95.170275  143.844950  61.092950
# 5   0.318575   73.684650  119.386600  43.012300
# 6   0.298500   76.706325  121.307700  46.210175
# 7   0.022475   96.267300  141.608575  63.956625
# 8  -0.113825   72.443375  152.937175  12.671125
# 9  -0.031775   69.308150  147.236725  14.053525
# 10 -0.068825   70.747350  149.775350  13.620400
# 11 -0.115100   72.492625  153.021175  12.668875
# 12  0.301925   76.698725  120.786400  46.933750
# 13  0.318825   72.015375  119.393000  41.407500
# 14  0.304025   71.964650  120.650050  37.560000
# 15  0.293150   74.962875  121.798325  40.751250
# 16  0.055000   69.197675  140.159950  13.487500
# 17  0.088875   67.891875  138.370025  13.237500
# 18  0.078100   67.989750  139.169100  13.112500
# 19  0.090850   67.881250  137.429975  13.212500
# 20 -0.232200   88.926175  159.223800  27.450000
# 21 -0.212600   88.738200  158.095100  27.962500
# 22 -0.204500   87.005350  157.602025  25.000000
# 23 -0.319850   93.093475  165.562175  28.650000
# 24  0.274925   83.872475  123.231750  59.572175
# 25  0.288800   80.010200  122.031100  53.120050
# 26  0.269700   81.125750  123.728925  55.068550
# 27  0.296225   81.740450  121.608325  58.090325
# 28  0.291700   71.884225  121.358500  34.774300
# 29  0.274900   72.382550  123.099700  32.898725
# 30  0.290125   71.598050  121.574275  34.496900
# 31  0.067350   85.331625  139.191775  45.146125
# 32 -0.214475   78.900225  159.802575  15.700825
# 33  0.219525   64.667475  128.037950  18.683100
# 34  0.258600   63.874575  125.007825  20.772875
# 35  0.033150   68.853325  142.801800  15.065800
# 36  0.271500   93.621500  123.461375  71.517650
# 37  0.259450   94.779475  124.486900  72.326175
# 38  0.262600   93.958400  124.159750  71.435125
# 39  0.065875  109.296850  139.213825  88.149125
# 40  0.311675   73.682525  120.114775  38.664125
# 41  0.314100   73.237450  119.907050  37.490375
# 42  0.316900   73.376025  119.646175  38.365650
# 43  0.170125   84.161150  131.752875  51.075250
#
#                                                 Model  Num_Features
# 0   RandomForestRegressor(n_estimators=500, n_jobs...           388  \
# 1   RandomForestRegressor(n_estimators=500, n_jobs...            70
# 2   RandomForestRegressor(n_estimators=500, n_jobs...            20
# 3   RandomForestRegressor(n_estimators=500, n_jobs...            20
# 4   MLPRegressor(max_iter=10000, random_state=2703...           388
# 5   MLPRegressor(max_iter=10000, random_state=2703...            50
# 6   MLPRegressor(max_iter=10000, random_state=2703...            10
# 7   MLPRegressor(max_iter=10000, random_state=2703...           150
# 8                                   SVR(gamma='auto')           388
# 9                                   SVR(gamma='auto')            10
# 10                                  SVR(gamma='auto')            10
# 11                                  SVR(gamma='auto')           330
# 12     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)           388
# 13     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)           150
# 14     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)            30
# 15     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)            10
# 16          LogisticRegression(random_state=27033074)           388
# 17          LogisticRegression(random_state=27033074)           320
# 18          LogisticRegression(random_state=27033074)           230
# 19          LogisticRegression(random_state=27033074)           100
# 20       DecisionTreeRegressor(random_state=27033074)           388
# 21       DecisionTreeRegressor(random_state=27033074)           300
# 22       DecisionTreeRegressor(random_state=27033074)            50
# 23       DecisionTreeRegressor(random_state=27033074)            10
# 24                                          RidgeCV()           388
# 25                                          RidgeCV()            50
# 26                                          RidgeCV()            10
# 27                                          RidgeCV()            20
# 28  XGBRegressor(base_score=0.5, booster='gbtree',...           388
# 29  XGBRegressor(base_score=0.5, booster='gbtree',...           280
# 30  XGBRegressor(base_score=0.5, booster='gbtree',...           250
# 31  XGBRegressor(base_score=0.5, booster='gbtree',...            30
# 32    GaussianProcessRegressor(random_state=27033074)           388
# 33    GaussianProcessRegressor(random_state=27033074)           210
# 34    GaussianProcessRegressor(random_state=27033074)           150
# 35    GaussianProcessRegressor(random_state=27033074)            20
# 36           AdaBoostRegressor(random_state=27033074)           388
# 37           AdaBoostRegressor(random_state=27033074)           300
# 38           AdaBoostRegressor(random_state=27033074)           330
# 39           AdaBoostRegressor(random_state=27033074)            60
# 40  GradientBoostingRegressor(n_estimators=500, ra...           388
# 41  GradientBoostingRegressor(n_estimators=500, ra...           330
# 42  GradientBoostingRegressor(n_estimators=500, ra...           270
# 43  GradientBoostingRegressor(n_estimators=500, ra...            20
#
#                                         Preprocessing Fea_Selection
# 0   QuantileTransformer(output_distribution='norma...           NaN  \
# 1   QuantileTransformer(output_distribution='norma...            kb
# 2   QuantileTransformer(output_distribution='norma...            rf
# 3   QuantileTransformer(output_distribution='norma...           NaN
# 4          QuantileTransformer(random_state=27033074)           NaN
# 5          QuantileTransformer(random_state=27033074)            kb
# 6          QuantileTransformer(random_state=27033074)            rf
# 7          QuantileTransformer(random_state=27033074)           NaN
# 8                                  PowerTransformer()           NaN
# 9                                  PowerTransformer()            kb
# 10                                 PowerTransformer()            rf
# 11                                 PowerTransformer()           NaN
# 12         QuantileTransformer(random_state=27033074)           NaN
# 13         QuantileTransformer(random_state=27033074)            kb
# 14         QuantileTransformer(random_state=27033074)            rf
# 15         QuantileTransformer(random_state=27033074)           NaN
# 16         QuantileTransformer(random_state=27033074)           NaN
# 17         QuantileTransformer(random_state=27033074)            kb
# 18         QuantileTransformer(random_state=27033074)            rf
# 19         QuantileTransformer(random_state=27033074)           NaN
# 20  QuantileTransformer(output_distribution='norma...           NaN
# 21  QuantileTransformer(output_distribution='norma...            kb
# 22  QuantileTransformer(output_distribution='norma...            rf
# 23  QuantileTransformer(output_distribution='norma...           NaN
# 24         QuantileTransformer(random_state=27033074)           NaN
# 25         QuantileTransformer(random_state=27033074)            kb
# 26         QuantileTransformer(random_state=27033074)            rf
# 27         QuantileTransformer(random_state=27033074)           NaN
# 28                                     MaxAbsScaler()           NaN
# 29                                     MaxAbsScaler()            kb
# 30                                     MaxAbsScaler()            rf
# 31                                     MaxAbsScaler()           NaN
# 32         QuantileTransformer(random_state=27033074)           NaN
# 33         QuantileTransformer(random_state=27033074)            kb
# 34         QuantileTransformer(random_state=27033074)            rf
# 35         QuantileTransformer(random_state=27033074)           NaN
# 36                                     MaxAbsScaler()           NaN
# 37                                     MaxAbsScaler()            kb
# 38                                     MaxAbsScaler()            rf
# 39                                     MaxAbsScaler()           NaN
# 40                                 PowerTransformer()           NaN
# 41                                 PowerTransformer()            kb
# 42                                 PowerTransformer()            rf
# 43                                 PowerTransformer()           NaN
#
#     Dim_Reduction  Var_Threshold
# 0               0           True
# 1               0           True
# 2               0           True
# 3               1           True
# 4               0           True
# 5               0           True
# 6               0           True
# 7               1           True
# 8               0           True
# 9               0           True
# 10              0           True
# 11              1           True
# 12              0           True
# 13              0           True
# 14              0           True
# 15              1           True
# 16              0          False
# 17              0          False
# 18              0          False
# 19              1          False
# 20              0          False
# 21              0          False
# 22              0          False
# 23              1          False
# 24              0           True
# 25              0           True
# 26              0           True
# 27              1           True
# 28              0          False
# 29              0          False
# 30              0          False
# 31              1          False
# 32              0           True
# 33              0           True
# 34              0           True
# 35              1           True
# 36              0          False
# 37              0          False
# 38              0          False
# 39              1          False
# 40              0           True
# 41              0           True
# 42              0           True
# 43              1           True

# %%
array = []
for i in f.Model:
    string = ''
    for c in i:
        if c == '(':
            break
        string += c

    if string == 'RandomForestClassifier':
        i = 'RF'
    elif string == 'MLPClassifier':
        i = 'MLP'
    elif string == 'SVC':
        i = 'SVM'
    elif string == 'KNeighborsClassifier':
        i = 'KNN'
    elif string == 'SGDClassifier':
        i = 'LGR'
    elif string == 'DecisionTreeClassifier':
        i = 'DT'
    elif string == 'RidgeClassifierCV':
        i = 'R'
    elif string == 'XGBClassifier':
        i = 'XG'
    elif string == 'GaussianProcessClassifier':
        i = 'GPC'
    elif string == 'AdaBoostClassifier':
        i = 'ADA'
    elif string == 'GradientBoostingClassifier':
        i = 'GB'

    array.append(i)
f.Model = array

# %%
array = []
for i in f.Preprocessing:
    string = i

    if string == 'StandardScaler()':
        i = 'StandardScaler'
    elif string == 'MinMaxScaler()':
        i = 'Min-maxScaler'
    elif string == 'MaxAbsScaler()':
        i = 'Max-absoluteScaler'
    elif string == 'RobustScaler()':
        i = 'RobustScaler'
    elif string == 'PowerTransformer()':
        i = 'PowerTransformer'
    elif string == 'QuantileTransformer(random_state=27033074)':
        i = 'QuantileTransformer_Uniform'
    elif string == "QuantileTransformer(output_distribution='normal', random_state=27033074)":
        i = 'QuantileTransformer_Normal'
    elif string == 'normalize':
        i = 'Normalisation'

    array.append(i)
f.Preprocessing = array

# %%
array = []
for i in f['R-square']:
    array.append(round(i, 4))
f['R-square'] = array

# %%
array = []
for i in f['MAE']:
    array.append(round(i, 4))
f.MAE = array

# %%
array = []
for i in f['RSME']:
    array.append(round(i, 4))
f.RSME = array

# %%
array = []
for i in f['MedAE']:
    array.append(round(i, 4))
f.MedAE = array

# %%
array = []
for i in range(len(f.index)):
    array.append(False)
f['Resampling'] = array

# %%
f = f.drop(['Fea_Selection', 'Dim_Reduction'], axis=1)

# %%
f
# Out:
#     R-square       MAE      RSME    MedAE
# 0     0.3182   74.5098  119.6488  41.7759  \
# 1     0.2792   73.3940  122.7656  39.6830
# 2     0.2950   72.7683  121.6267  38.2920
# 3     0.2754   76.1112  123.0704  41.0894
# 4    -0.0069   95.1703  143.8450  61.0930
# 5     0.3186   73.6847  119.3866  43.0123
# 6     0.2985   76.7063  121.3077  46.2102
# 7     0.0225   96.2673  141.6086  63.9566
# 8    -0.1138   72.4434  152.9372  12.6711
# 9    -0.0318   69.3081  147.2367  14.0535
# 10   -0.0688   70.7474  149.7754  13.6204
# 11   -0.1151   72.4926  153.0212  12.6689
# 12    0.3019   76.6987  120.7864  46.9338
# 13    0.3188   72.0154  119.3930  41.4075
# 14    0.3040   71.9647  120.6500  37.5600
# 15    0.2932   74.9629  121.7983  40.7512
# 16    0.0550   69.1977  140.1599  13.4875
# 17    0.0889   67.8919  138.3700  13.2375
# 18    0.0781   67.9898  139.1691  13.1125
# 19    0.0909   67.8812  137.4300  13.2125
# 20   -0.2322   88.9262  159.2238  27.4500
# 21   -0.2126   88.7382  158.0951  27.9625
# 22   -0.2045   87.0053  157.6020  25.0000
# 23   -0.3198   93.0935  165.5622  28.6500
# 24    0.2749   83.8725  123.2318  59.5722
# 25    0.2888   80.0102  122.0311  53.1201
# 26    0.2697   81.1257  123.7289  55.0686
# 27    0.2962   81.7404  121.6083  58.0903
# 28    0.2917   71.8842  121.3585  34.7743
# 29    0.2749   72.3825  123.0997  32.8987
# 30    0.2901   71.5981  121.5743  34.4969
# 31    0.0673   85.3316  139.1918  45.1461
# 32   -0.2145   78.9002  159.8026  15.7008
# 33    0.2195   64.6675  128.0379  18.6831
# 34    0.2586   63.8746  125.0078  20.7729
# 35    0.0331   68.8533  142.8018  15.0658
# 36    0.2715   93.6215  123.4614  71.5177
# 37    0.2595   94.7795  124.4869  72.3262
# 38    0.2626   93.9584  124.1598  71.4351
# 39    0.0659  109.2969  139.2138  88.1491
# 40    0.3117   73.6825  120.1148  38.6641
# 41    0.3141   73.2374  119.9070  37.4904
# 42    0.3169   73.3760  119.6462  38.3657
# 43    0.1701   84.1612  131.7529  51.0752
#
#                                                 Model  Num_Features
# 0   RandomForestRegressor(n_estimators=500, n_jobs...           388  \
# 1   RandomForestRegressor(n_estimators=500, n_jobs...            70
# 2   RandomForestRegressor(n_estimators=500, n_jobs...            20
# 3   RandomForestRegressor(n_estimators=500, n_jobs...            20
# 4   MLPRegressor(max_iter=10000, random_state=2703...           388
# 5   MLPRegressor(max_iter=10000, random_state=2703...            50
# 6   MLPRegressor(max_iter=10000, random_state=2703...            10
# 7   MLPRegressor(max_iter=10000, random_state=2703...           150
# 8                                   SVR(gamma='auto')           388
# 9                                   SVR(gamma='auto')            10
# 10                                  SVR(gamma='auto')            10
# 11                                  SVR(gamma='auto')           330
# 12     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)           388
# 13     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)           150
# 14     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)            30
# 15     KNeighborsRegressor(n_jobs=-1, n_neighbors=10)            10
# 16          LogisticRegression(random_state=27033074)           388
# 17          LogisticRegression(random_state=27033074)           320
# 18          LogisticRegression(random_state=27033074)           230
# 19          LogisticRegression(random_state=27033074)           100
# 20       DecisionTreeRegressor(random_state=27033074)           388
# 21       DecisionTreeRegressor(random_state=27033074)           300
# 22       DecisionTreeRegressor(random_state=27033074)            50
# 23       DecisionTreeRegressor(random_state=27033074)            10
# 24                                          RidgeCV()           388
# 25                                          RidgeCV()            50
# 26                                          RidgeCV()            10
# 27                                          RidgeCV()            20
# 28  XGBRegressor(base_score=0.5, booster='gbtree',...           388
# 29  XGBRegressor(base_score=0.5, booster='gbtree',...           280
# 30  XGBRegressor(base_score=0.5, booster='gbtree',...           250
# 31  XGBRegressor(base_score=0.5, booster='gbtree',...            30
# 32    GaussianProcessRegressor(random_state=27033074)           388
# 33    GaussianProcessRegressor(random_state=27033074)           210
# 34    GaussianProcessRegressor(random_state=27033074)           150
# 35    GaussianProcessRegressor(random_state=27033074)            20
# 36           AdaBoostRegressor(random_state=27033074)           388
# 37           AdaBoostRegressor(random_state=27033074)           300
# 38           AdaBoostRegressor(random_state=27033074)           330
# 39           AdaBoostRegressor(random_state=27033074)            60
# 40  GradientBoostingRegressor(n_estimators=500, ra...           388
# 41  GradientBoostingRegressor(n_estimators=500, ra...           330
# 42  GradientBoostingRegressor(n_estimators=500, ra...           270
# 43  GradientBoostingRegressor(n_estimators=500, ra...            20
#
#                   Preprocessing Fea_Selection  Dim_Reduction  Var_Threshold
# 0    QuantileTransformer_Normal           NaN              0           True
# 1    QuantileTransformer_Normal            kb              0           True
# 2    QuantileTransformer_Normal            rf              0           True
# 3    QuantileTransformer_Normal           NaN              1           True
# 4   QuantileTransformer_Uniform           NaN              0           True
# 5   QuantileTransformer_Uniform            kb              0           True
# 6   QuantileTransformer_Uniform            rf              0           True
# 7   QuantileTransformer_Uniform           NaN              1           True
# 8              PowerTransformer           NaN              0           True
# 9              PowerTransformer            kb              0           True
# 10             PowerTransformer            rf              0           True
# 11             PowerTransformer           NaN              1           True
# 12  QuantileTransformer_Uniform           NaN              0           True
# 13  QuantileTransformer_Uniform            kb              0           True
# 14  QuantileTransformer_Uniform            rf              0           True
# 15  QuantileTransformer_Uniform           NaN              1           True
# 16  QuantileTransformer_Uniform           NaN              0          False
# 17  QuantileTransformer_Uniform            kb              0          False
# 18  QuantileTransformer_Uniform            rf              0          False
# 19  QuantileTransformer_Uniform           NaN              1          False
# 20   QuantileTransformer_Normal           NaN              0          False
# 21   QuantileTransformer_Normal            kb              0          False
# 22   QuantileTransformer_Normal            rf              0          False
# 23   QuantileTransformer_Normal           NaN              1          False
# 24  QuantileTransformer_Uniform           NaN              0           True
# 25  QuantileTransformer_Uniform            kb              0           True
# 26  QuantileTransformer_Uniform            rf              0           True
# 27  QuantileTransformer_Uniform           NaN              1           True
# 28           Max-absoluteScaler           NaN              0          False
# 29           Max-absoluteScaler            kb              0          False
# 30           Max-absoluteScaler            rf              0          False
# 31           Max-absoluteScaler           NaN              1          False
# 32  QuantileTransformer_Uniform           NaN              0           True
# 33  QuantileTransformer_Uniform            kb              0           True
# 34  QuantileTransformer_Uniform            rf              0           True
# 35  QuantileTransformer_Uniform           NaN              1           True
# 36           Max-absoluteScaler           NaN              0          False
# 37           Max-absoluteScaler            kb              0          False
# 38           Max-absoluteScaler            rf              0          False
# 39           Max-absoluteScaler           NaN              1          False
# 40             PowerTransformer           NaN              0           True
# 41             PowerTransformer            kb              0           True
# 42             PowerTransformer            rf              0           True
# 43             PowerTransformer           NaN              1           True

# %%
f.to_csv('Optimal_FeatureSelection.csv', index=False)

# %%
len(f.index)
# Out:
# 44
