# %%
import pandas as pd
import numpy as np
import math

# %%
f = pd.read_csv('best_vt_novt.csv', sep=',', keep_default_na=True)
f
# Out:
#     R-square        MAE        RSME      MedAE
# 0   0.318175  74.509750  119.648850  41.775900  \
# 1  -0.006950  95.170275  143.844950  61.092950
# 2  -0.113825  72.443375  152.937175  12.671125
# 3   0.301925  76.698725  120.786400  46.933750
# 4   0.055000  69.197675  140.159950  13.487500
# 5  -0.232200  88.926175  159.223800  27.450000
# 6   0.274925  83.872475  123.231750  59.572175
# 7   0.291700  71.884225  121.358500  34.774300
# 8  -0.214475  78.900225  159.802575  15.700825
# 9   0.271500  93.621500  123.461375  71.517650
# 10  0.311675  73.682525  120.114775  38.664125
#
#                                                 Model  Num_Features
# 0   RandomForestRegressor(n_estimators=500, n_jobs...           388  \
# 1   MLPRegressor(max_iter=10000, random_state=2703...           388
# 2                                   SVR(gamma='auto')           388
# 3      KNeighborsRegressor(n_jobs=-1, n_neighbors=10)           388
# 4           LogisticRegression(random_state=27033074)           388
# 5        DecisionTreeRegressor(random_state=27033074)           388
# 6                                           RidgeCV()           388
# 7   XGBRegressor(base_score=0.5, booster='gbtree',...           388
# 8     GaussianProcessRegressor(random_state=27033074)           388
# 9            AdaBoostRegressor(random_state=27033074)           388
# 10  GradientBoostingRegressor(n_estimators=500, ra...           388
#
#                                         Preprocessing  Fea_Selection
# 0   QuantileTransformer(output_distribution='norma...            NaN  \
# 1          QuantileTransformer(random_state=27033074)            NaN
# 2                                  PowerTransformer()            NaN
# 3          QuantileTransformer(random_state=27033074)            NaN
# 4          QuantileTransformer(random_state=27033074)            NaN
# 5   QuantileTransformer(output_distribution='norma...            NaN
# 6          QuantileTransformer(random_state=27033074)            NaN
# 7                                      MaxAbsScaler()            NaN
# 8          QuantileTransformer(random_state=27033074)            NaN
# 9                                      MaxAbsScaler()            NaN
# 10                                 PowerTransformer()            NaN
#
#     Dim_Reduction  Var_Threshold
# 0               0           True
# 1               0           True
# 2               0           True
# 3               0           True
# 4               0          False
# 5               0          False
# 6               0           True
# 7               0          False
# 8               0           True
# 9               0          False
# 10              0           True

# %%
array = []
for i in f.Model:
    string = ''
    for c in i:
        if c == '(':
            break
        string += c

    if string == 'RandomForestClassifier':
        i = 'RF'
    elif string == 'MLPClassifier':
        i = 'MLP'
    elif string == 'SVC':
        i = 'SVM'
    elif string == 'KNeighborsClassifier':
        i = 'KNN'
    elif string == 'SGDClassifier':
        i = 'LGR'
    elif string == 'DecisionTreeClassifier':
        i = 'DT'
    elif string == 'RidgeClassifierCV':
        i = 'R'
    elif string == 'XGBClassifier':
        i = 'XG'
    elif string == 'GaussianProcessClassifier':
        i = 'GPC'
    elif string == 'AdaBoostClassifier':
        i = 'ADA'
    elif string == 'GradientBoostingClassifier':
        i = 'GB'

    array.append(i)
f.Model = array

# %%
array = []
for i in f.Preprocessing:
    string = i

    if string == 'StandardScaler()':
        i = 'StandardScaler'
    elif string == 'MinMaxScaler()':
        i = 'Min-maxScaler'
    elif string == 'MaxAbsScaler()':
        i = 'Max-absoluteScaler'
    elif string == 'RobustScaler()':
        i = 'RobustScaler'
    elif string == 'PowerTransformer()':
        i = 'PowerTransformer'
    elif string == 'QuantileTransformer(random_state=27033074)':
        i = 'QuantileTransformer_Uniform'
    elif string == "QuantileTransformer(output_distribution='normal', random_state=27033074)":
        i = 'QuantileTransformer_Normal'
    elif string == 'normalize':
        i = 'Normalisation'

    array.append(i)
f.Preprocessing = array

# %%
array = []
for i in f['R-square']:
    array.append(round(i, 4))
f['R-square'] = array

# %%
array = []
for i in f['MAE']:
    array.append(round(i, 4))
f.MAE = array

# %%
array = []
for i in f['RSME']:
    array.append(round(i, 4))
f.RSME = array

# %%
array = []
for i in f['MedAE']:
    array.append(round(i, 4))
f.MedAE = array

# %%
array = []
for i in range(len(f.index)):
    array.append(False)
f['Resampling'] = array

# %%
f = f.drop(['Fea_Selection', 'Dim_Reduction'], axis=1)

# %%
f
# Out:
#     R-square      MAE      RSME    MedAE
# 0     0.3182  74.5098  119.6488  41.7759  \
# 1    -0.0069  95.1703  143.8450  61.0930
# 2    -0.1138  72.4434  152.9372  12.6711
# 3     0.3019  76.6987  120.7864  46.9338
# 4     0.0550  69.1977  140.1599  13.4875
# 5    -0.2322  88.9262  159.2238  27.4500
# 6     0.2749  83.8725  123.2318  59.5722
# 7     0.2917  71.8842  121.3585  34.7743
# 8    -0.2145  78.9002  159.8026  15.7008
# 9     0.2715  93.6215  123.4614  71.5177
# 10    0.3117  73.6825  120.1148  38.6641
#
#                                                 Model  Num_Features
# 0   RandomForestRegressor(n_estimators=500, n_jobs...           388  \
# 1   MLPRegressor(max_iter=10000, random_state=2703...           388
# 2                                   SVR(gamma='auto')           388
# 3      KNeighborsRegressor(n_jobs=-1, n_neighbors=10)           388
# 4           LogisticRegression(random_state=27033074)           388
# 5        DecisionTreeRegressor(random_state=27033074)           388
# 6                                           RidgeCV()           388
# 7   XGBRegressor(base_score=0.5, booster='gbtree',...           388
# 8     GaussianProcessRegressor(random_state=27033074)           388
# 9            AdaBoostRegressor(random_state=27033074)           388
# 10  GradientBoostingRegressor(n_estimators=500, ra...           388
#
#                   Preprocessing  Var_Threshold
# 0    QuantileTransformer_Normal           True
# 1   QuantileTransformer_Uniform           True
# 2              PowerTransformer           True
# 3   QuantileTransformer_Uniform           True
# 4   QuantileTransformer_Uniform          False
# 5    QuantileTransformer_Normal          False
# 6   QuantileTransformer_Uniform           True
# 7            Max-absoluteScaler          False
# 8   QuantileTransformer_Uniform           True
# 9            Max-absoluteScaler          False
# 10             PowerTransformer           True

# %%
f.to_csv('Optimal_VarianceThreshold.csv', index=False)

# %%
len(f.index)
# Out:
# 11
