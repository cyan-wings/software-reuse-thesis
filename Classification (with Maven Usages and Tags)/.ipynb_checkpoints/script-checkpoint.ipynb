# %%
import pandas as pd
import numpy as np
import math

# %%
f = pd.read_csv('best-model-tunings.csv', sep=',', keep_default_na=True)
f
# Out:
#     F1-Score  Precision    Recall  Accuracy
# 0   0.782125   0.782750  0.784625  0.800750  \
# 1   0.763450   0.779450  0.751675  0.787900
# 2   0.786400   0.766075  0.810050  0.799275
# 3   0.780125   0.779400  0.783850  0.798100
# 4   0.765950   0.721950  0.827575  0.769050
# 5   0.718600   0.717750  0.722550  0.742625
# 6   0.791675   0.779400  0.807050  0.806075
# 7   0.774825   0.730825  0.831625  0.779125
# 8   0.775375   0.713650  0.851275  0.774200
# 9   0.763550   0.754250  0.775775  0.781375
# 10  0.773050   0.781450  0.767950  0.794525
#
#                                                 Model  Num_Features
# 0   RandomForestClassifier(n_estimators=500, n_job...           160  \
# 1   MLPClassifier(max_iter=10000, random_state=270...           160
# 2            SVC(gamma='auto', random_state=27033074)           160
# 3     KNeighborsClassifier(n_jobs=-1, n_neighbors=10)           320
# 4   SGDClassifier(loss='log', n_jobs=-1, random_st...            40
# 5       DecisionTreeClassifier(random_state=27033074)            30
# 6                                 RidgeClassifierCV()            20
# 7   XGBClassifier(base_score=None, booster=None, c...           370
# 8    GaussianProcessClassifier(random_state=27033074)           270
# 9           AdaBoostClassifier(random_state=27033074)           210
# 10  GradientBoostingClassifier(n_estimators=500, r...           401
#
#                                         Preprocessing Fea_Selection
# 0                                      MaxAbsScaler()            kb  \
# 1                                  PowerTransformer()            rf
# 2          QuantileTransformer(random_state=27033074)            kb
# 3          QuantileTransformer(random_state=27033074)            rf
# 4                                           normalize           NaN
# 5   QuantileTransformer(output_distribution='norma...            rf
# 6          QuantileTransformer(random_state=27033074)           NaN
# 7                                           normalize            rf
# 8                                           normalize            kb
# 9          QuantileTransformer(random_state=27033074)            rf
# 10  QuantileTransformer(output_distribution='norma...           NaN
#
#     Dim_Reduction  Var_Threshold  support  resampling
# 0               0           True       60        True
# 1               0           True       60       False
# 2               0           True       60        True
# 3               0          False       60       False
# 4               1          False       60       False
# 5               0          False       60        True
# 6               1           True       60        True
# 7               0          False       60        True
# 8               0          False       60       False
# 9               0           True       60        True
# 10              0           True       60       False

# %%
array = []
for i in f.Model:
    string = ''
    for c in i:
        if c == '(':
            break
        string += c

    if string == 'RandomForestClassifier':
        i = 'RF'
    elif string == 'MLPClassifier':
        i = 'MLP'
    elif string == 'SVC':
        i = 'SVM'
    elif string == 'KNeighborsClassifier':
        i = 'KNN'
    elif string == 'SGDClassifier':
        i = 'LGR'
    elif string == 'DecisionTreeClassifier':
        i = 'DT'
    elif string == 'RidgeClassifierCV':
        i = 'R'
    elif string == 'XGBClassifier':
        i = 'XG'
    elif string == 'GaussianProcessClassifier':
        i = 'GPC'
    elif string == 'AdaBoostClassifier':
        i = 'ADA'
    elif string == 'GradientBoostingClassifier':
        i = 'GB'

    array.append(i)
f.Model = array

# %%
array = []
for i in f.Preprocessing:
    string = i

    if string == 'StandardScaler()':
        i = 'StandardScaler'
    elif string == 'MinMaxScaler()':
        i = 'Min-maxScaler'
    elif string == 'MaxAbsScaler()':
        i = 'Max-absoluteScaler'
    elif string == 'RobustScaler()':
        i = 'RobustScaler'
    elif string == 'PowerTransformer()':
        i = 'PowerTransformer'
    elif string == 'QuantileTransformer(random_state=27033074)':
        i = 'QuantileTransformer_Uniform'
    elif string == "QuantileTransformer(output_distribution='normal', random_state=27033074)":
        i = 'QuantileTransformer_Normal'
    elif string == 'normalize':
        i = 'Normalisation'

    array.append(i)
f.Preprocessing = array

# %%
array = []
for i in f['F1-Score']:
    array.append(round(i, 4))
f['F1-Score'] = array

# %%
array = []
for i in f['Precision']:
    array.append(round(i, 4))
f.Precision = array

# %%
array = []
for i in f['Recall']:
    array.append(round(i, 4))
f.Recall = array

# %%
array = []
for i in f['Accuracy']:
    array.append(round(i, 4))
f.Accuracy = array

# %%
array = []
for i in range(len(f.index)):
    array.append(False)
f['Resampling'] = array

# %%
f = f.drop(['support', 'Fea_Selection', 'Dim_Reduction'], axis=1)

# %%
f
# Out:
#     F1-Score  Precision  Recall  Accuracy Model  Num_Features
# 0     0.7821     0.7828  0.7846    0.8008    RF           160  \
# 1     0.7634     0.7794  0.7517    0.7879   MLP           160
# 2     0.7864     0.7661  0.8101    0.7993   SVM           160
# 3     0.7801     0.7794  0.7838    0.7981   KNN           320
# 4     0.7659     0.7219  0.8276    0.7691   LGR            40
# 5     0.7186     0.7177  0.7226    0.7426    DT            30
# 6     0.7917     0.7794  0.8070    0.8061     R            20
# 7     0.7748     0.7308  0.8316    0.7791    XG           370
# 8     0.7754     0.7137  0.8513    0.7742   GPC           270
# 9     0.7636     0.7543  0.7758    0.7814   ADA           210
# 10    0.7731     0.7815  0.7680    0.7945    GB           401
#
#                   Preprocessing Fea_Selection  Dim_Reduction  Var_Threshold
# 0            Max-absoluteScaler            kb              0           True  \
# 1              PowerTransformer            rf              0           True
# 2   QuantileTransformer_Uniform            kb              0           True
# 3   QuantileTransformer_Uniform            rf              0          False
# 4                 Normalisation           NaN              1          False
# 5    QuantileTransformer_Normal            rf              0          False
# 6   QuantileTransformer_Uniform           NaN              1           True
# 7                 Normalisation            rf              0          False
# 8                 Normalisation            kb              0          False
# 9   QuantileTransformer_Uniform            rf              0           True
# 10   QuantileTransformer_Normal           NaN              0           True
#
#     support  resampling
# 0        60        True
# 1        60       False
# 2        60        True
# 3        60       False
# 4        60       False
# 5        60        True
# 6        60        True
# 7        60        True
# 8        60       False
# 9        60        True
# 10       60       False

# %%
f.to_csv('Optimal_Model_Tunings.csv', index=False)

# %%
len(f.index)
# Out:
# 11
