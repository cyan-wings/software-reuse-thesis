# %%
import pandas as pd
import numpy as np
import math

# %%
f = pd.read_csv('best-model-tunings.csv', sep=',', keep_default_na=True)
f
# Out:
#     F1-Score  Precision    Recall  Accuracy
# 0   0.781575   0.782925  0.783350  0.800375  \
# 1   0.765975   0.777550  0.757525  0.788575
# 2   0.786400   0.766075  0.810050  0.799275
# 3   0.783625   0.774825  0.795850  0.799275
# 4   0.767775   0.725400  0.825050  0.771325
# 5   0.718700   0.719200  0.720350  0.743000
# 6   0.785825   0.778650  0.795800  0.802250
# 7   0.778500   0.788900  0.771725  0.800100
# 8   0.780025   0.730300  0.840025  0.783550
# 9   0.762100   0.750375  0.777075  0.779100
# 10  0.779700   0.788175  0.774550  0.801150
#
#                                                 Model  Num_Features
# 0   RandomForestClassifier(n_estimators=500, n_job...           160  \
# 1   MLPClassifier(max_iter=10000, random_state=270...           190
# 2            SVC(gamma='auto', random_state=27033074)           160
# 3     KNeighborsClassifier(n_jobs=-1, n_neighbors=10)           330
# 4   SGDClassifier(loss='log', n_jobs=-1, random_st...            90
# 5       DecisionTreeClassifier(random_state=27033074)            90
# 6                                 RidgeClassifierCV()           170
# 7   XGBClassifier(base_score=None, booster=None, c...           400
# 8    GaussianProcessClassifier(random_state=27033074)           490
# 9           AdaBoostClassifier(random_state=27033074)           220
# 10  GradientBoostingClassifier(n_estimators=500, r...           200
#
#                                         Preprocessing Fea_Selection
# 0                                    StandardScaler()            kb  \
# 1                                  PowerTransformer()            rf
# 2          QuantileTransformer(random_state=27033074)            kb
# 3          QuantileTransformer(random_state=27033074)            rf
# 4                                           normalize           NaN
# 5                                      MinMaxScaler()            rf
# 6          QuantileTransformer(random_state=27033074)            kb
# 7                                      MaxAbsScaler()            kb
# 8                                           normalize            kb
# 9   QuantileTransformer(output_distribution='norma...            kb
# 10                                                NaN            kb
#
#     Dim_Reduction  Var_Threshold  support  resampling
# 0               0           True       60        True
# 1               0          False       60       False
# 2               0           True       60        True
# 3               0          False       60       False
# 4               1          False       60       False
# 5               0           True       60        True
# 6               0          False       60       False
# 7               0          False       60       False
# 8               0          False       60       False
# 9               0           True       60        True
# 10              0           True       60       False

# %%
array = []
for i in f.Model:
    string = ''
    for c in i:
        if c == '(':
            break
        string += c

    if string == 'RandomForestClassifier':
        i = 'RF'
    elif string == 'MLPClassifier':
        i = 'MLP'
    elif string == 'SVC':
        i = 'SVM'
    elif string == 'KNeighborsClassifier':
        i = 'KNN'
    elif string == 'SGDClassifier':
        i = 'LGR'
    elif string == 'DecisionTreeClassifier':
        i = 'DT'
    elif string == 'RidgeClassifierCV':
        i = 'R'
    elif string == 'XGBClassifier':
        i = 'XG'
    elif string == 'GaussianProcessClassifier':
        i = 'GPC'
    elif string == 'AdaBoostClassifier':
        i = 'ADA'
    elif string == 'GradientBoostingClassifier':
        i = 'GB'

    array.append(i)
f.Model = array

# %%
array = []
for i in f.Preprocessing:
    string = i

    if string == 'StandardScaler()':
        i = 'StandardScaler'
    elif string == 'MinMaxScaler()':
        i = 'Min-maxScaler'
    elif string == 'MaxAbsScaler()':
        i = 'Max-absoluteScaler'
    elif string == 'RobustScaler()':
        i = 'RobustScaler'
    elif string == 'PowerTransformer()':
        i = 'PowerTransformer'
    elif string == 'QuantileTransformer(random_state=27033074)':
        i = 'QuantileTransformer_Uniform'
    elif string == "QuantileTransformer(output_distribution='normal', random_state=27033074)":
        i = 'QuantileTransformer_Normal'
    elif string == 'normalize':
        i = 'Normalisation'

    array.append(i)
f.Preprocessing = array

# %%
array = []
for i in f['F1-Score']:
    array.append(round(i, 4))
f['F1-Score'] = array

# %%
array = []
for i in f['Precision']:
    array.append(round(i, 4))
f.Precision = array

# %%
array = []
for i in f['Recall']:
    array.append(round(i, 4))
f.Recall = array

# %%
array = []
for i in f['Accuracy']:
    array.append(round(i, 4))
f.Accuracy = array

# %%
array = []
for i in range(len(f.index)):
    array.append(False)
f['Resampling'] = array

# %%
f = f.drop(['support', 'Fea_Selection', 'Dim_Reduction'], axis=1)

# %%
f
# Out:
#     F1-Score  Precision  Recall  Accuracy Model  Num_Features
# 0     0.7816     0.7829  0.7833    0.8004    RF           160  \
# 1     0.7660     0.7775  0.7575    0.7886   MLP           190
# 2     0.7864     0.7661  0.8101    0.7993   SVM           160
# 3     0.7836     0.7748  0.7958    0.7993   KNN           330
# 4     0.7678     0.7254  0.8251    0.7713   LGR            90
# 5     0.7187     0.7192  0.7204    0.7430    DT            90
# 6     0.7858     0.7787  0.7958    0.8022     R           170
# 7     0.7785     0.7889  0.7717    0.8001    XG           400
# 8     0.7800     0.7303  0.8400    0.7835   GPC           490
# 9     0.7621     0.7504  0.7771    0.7791   ADA           220
# 10    0.7797     0.7882  0.7745    0.8012    GB           200
#
#                   Preprocessing Fea_Selection  Dim_Reduction  Var_Threshold
# 0                StandardScaler            kb              0           True  \
# 1              PowerTransformer            rf              0          False
# 2   QuantileTransformer_Uniform            kb              0           True
# 3   QuantileTransformer_Uniform            rf              0          False
# 4                 Normalisation           NaN              1          False
# 5                 Min-maxScaler            rf              0           True
# 6   QuantileTransformer_Uniform            kb              0          False
# 7            Max-absoluteScaler            kb              0          False
# 8                 Normalisation            kb              0          False
# 9    QuantileTransformer_Normal            kb              0           True
# 10                          NaN            kb              0           True
#
#     support  resampling
# 0        60        True
# 1        60       False
# 2        60        True
# 3        60       False
# 4        60       False
# 5        60        True
# 6        60       False
# 7        60       False
# 8        60       False
# 9        60        True
# 10       60       False

# %%
f.to_csv('Optimal_Model_Tunings.csv', index=False)

# %%
len(f.index)
# Out:
# 11
